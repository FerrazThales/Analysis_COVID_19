# %% [markdown]
# <a href="https://colab.research.google.com/github/FerrazThales/Analysis_COVID_19/blob/main/Panorama_da_COVID_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Panorama da COVID-19
#
# COVID-19 é uma doença infecciosa causada pelo vírus SARS-CoV-2. As primeiras amostras desta doença foram encontradas na cidade de Wuhan (China) em Dezembro de 2019. Dado o alto grau de transmissibilidade e letalidade deste vírus, as principais nações do mundo decretaram **medidas restritivas** severas e a obrigatoriedade do uso de **máscaras** para tentar conter o avanço desta doença.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de *pessoas infectadas*, os principais sintomas desta enfermidade são:
#
# * Febre ou calafrios
# * Tosse
# * Falta de Ar
# * Dores de garganta e no Corpo
# * Fadiga
# * Anosmia (ausência de olfato)
# * Mais sintomas podem ser vistos em: [Sintomas Covid]('https://www.tuasaude.com/coronavirus/)
#
# A detecção deste vírus, ocorre principalmente através de exames PCR. Estes exames medem a quantidade de uma proteína (C-reativa) no corpo dos seres humanos. Quando está havendo um processo inflamatório ou infeccioso no corpo, há um aumento considerável desta proteína. Com isso, são coletados materiais infecciosos provenientes da garganta ou nariz do paciente e para análise destas amostras se utiliza biologia molecular para encontrar os materiais genéticos do vírus da COVID-19.
#
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/carlosfab/dsnp2/master/img/covid19.jpg"></center>
#
# Para tentar conter a pandemia ocasionada pela COVID-19, surgiu uma *corrida* de vacinas proporcionada pelas principais empresas farmacêuticas do mundo. Em tempo recorde,aproximadamente um ano, foram concebidas inúmeras vacinas realizadas com diferentes técnicas científicas, chegando algumas a atingir eficiências maiores que 90% após a aplicação da segunda dose.
#
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 e exaltar as conquistas científicas, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados utilizados neste projeto são baseados no [GitHub sobre a COVID](https://github.com/owid/covid-19-data/tree/master/public/data). Nele, estão sendo atualizadas diariamente as informações sobre a  COVID-19. É importante ressaltar, que este trabalho de obtenção de dados é mantido por uma organização chamada [Our World in Data](https://ourworldindata.org/about).
#
# Esta organização surgiu com o intuito de tornar os dados acessíveis de diferentes problemas do mundo. Além da COVID, existem estudos sobre a fome, a pobreza, mudanças climáticas, guerras e a desigualdade. Desta forma , esta entidade se propõe mudar o mundo e nosso futuro através de **pesquisas** e **análise** de dados.
#
# Obviamente, por se tratar de temas que incomodam muitos políticos, podem existir divergências ou ausência na divulgação de certos dados. Inclusive no Brasil, a imprensa criou um orgão próprio para mensurar a gravidade da pandemia, o [Consórcio da Imprensa](https://pt.wikipedia.org/wiki/Cons%C3%B3rcio_de_Ve%C3%ADculos_de_Imprensa) devido ao governo federal, naquele momento, estar restringindo o acesso a determinados dados. Por isso, sempre é importante se referenciar a fontes confiáveis e que tem respaldo científico.
#
# ### Dicionário de Variáveis
# * *iso code* : códigos de três-letras da Organização Internacional para Padronização (ISO) para representar localidades [Códigos ISO](https://pt.wikipedia.org/wiki/ISO_3166-1_alfa-3)
# * *continent* : Continente em que está localizado o País
# * *location* : País
# * *total_cases* : total de casos confirmados com COVID-19
# * *new_cases* : novos casos de COVID-19 confirmados
# * *new_cases_smoothed* : média móvel (7 dias) de novos casos
# * *total_deaths* : total de mortes confirmadas relacionadas a COVID-19
# * *new_deaths* : novos mortes relacionadas COVID-19 confirmadas
# * *new_deaths_smoothed* : média móvel (7 dias) de novas mortes relacionadas a COVID-19
# * *total_cases_per_million* : total de casos de COVID-19 por milhão de pessoas
# * *new_cases_per_million* : total de novos casos de COVID-19 por milhão de pessoas
# * *new_cases_smoothed_per_million* : média móvel (7 dias) de novos casos por milhão de pessoas
# * *total_deaths_per_million* : total de mortes relacionadas ao COVID-19 por milhão de pessoas
# * *new_deaths_per_million* : total de novas mortes relacionadas ao COVID-19 por milhão de pessoas
# * *new_deaths_smoothed_per_million* : médial móvel (7 dias) do número de mortes relacionadas a COVID-19 por milhão de pessoas
# * *reproduction_rate* : estimativa da taxa de reprodução do vírus da COVID-19, ou seja, a quantidade de pessoas que um infectado pode contagiar
# * *icu_patients* : número de pacientes com COVID-19 na UTI no dia registrado
# * *icu_patients_per_million* : número de pacientes com COVID-19 na UTI no dia registrado por milhão de pessoas
# * *hosp_patients* : número de pacientes com COVID-19 no dia registrado
# * *hosp_patients_per_million* : número de pacientes com COVID-19 no dia registrado por milhão de pessoas
# * *weekly_icu_admissions* :
# * *weekly_icu_admissions_per_million* :
# * *weekly_hosp_admissions* :
# * *weekly_hosp_admissions_per_million* :
# * *new_tests* :
# * *total_tests* :
# * *total_tests_per_thousand* :
# * *new_tests_per_thousand* :
# * *new_tests_smoothed* :
# * *new_tests_smoothed_per_thousand* :
# * *positive_rate* :
# * *tests_per_case* :
# * *tests_units* :
# * *total_vaccinations* :
# * *people_vaccinated* :
# * *people_fully_vaccinated* :
# * *total_boosters* :
# * *new_vaccinations* :
# * *new_vaccinations_smoothed* :
# * *total_vaccinations_per_hundred* :
# * *people_vaccinated_per_hundred* :
# * *people_fully_vaccinated_per_hundred* :
# * *total_boosters_per_hundred* :
# * *new_vaccinations_smoothed_per_million* :
# * *stringency_index* :
# * *population* :
# * *population_density* :
# * *median_age* : Média de idade da população baseado na projeção das Nações Unidas para o ano de 2020
# * *aged_65_older* :
# * *aged_70_older* :
# * *gdp_per_capita* :
# * *extreme_poverty* :
# * *cardiovasc_death_rate* :
# * *diabetes_prevalence* :
# * *female_smokers* :
# * *male_smokers* :
# * *handwashing_facilities* :
# * *hospital_beds_per_thousand* :
# * *life_expectancy* :
# * *human_development_index* :
# * *excess_mortality* :

# %%
#instalando as bibliotecas necessárias para trabalhar com datasets muito grandes
# !pip install dask[dataframe] --upgrade -q
# !pip install aiohttp -q
# !pip install bar_chart_race -q
# Out:
#      |████████████████████████████████| 118 kB 13.0 MB/s
#      |████████████████████████████████| 1.3 MB 13.0 MB/s
#      |████████████████████████████████| 294 kB 48.9 MB/s
#      |████████████████████████████████| 142 kB 45.7 MB/s
#      |████████████████████████████████| 156 kB 11.9 MB/s

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
from dask import dataframe as dd
import bar_chart_race as bcr

#setando o pandas para enxegarmos todas as colunas do dataframe
pd.get_option('display.max_columns')


# importar o dataset COVID-19 para um DataFrame e colocando as datas como index
df_covid = pd.read_csv('https://covid.ourworldindata.org/data/owid-covid-data.csv',index_col='date',parse_dates=True)

# %%
## perguntas: 

## a população que mais testou foi a que teve mais individuos no hospital?
## novos caos ao longo do tempo para o mundo e para o Brasil
## Como os novos caos se relacionam com a vacinação?

# %%
df_covid.T
# Out:
# date                         2020-02-24   2020-02-25  ... 2021-08-28 2021-08-29
# iso_code                            AFG          AFG  ...        ZWE        ZWE
# continent                          Asia         Asia  ...     Africa     Africa
# location                    Afghanistan  Afghanistan  ...   Zimbabwe   Zimbabwe
# total_cases                           1            1  ...     124367     124437
# new_cases                             1            0  ...        131         70
# ...                                 ...          ...  ...        ...        ...
# handwashing_facilities           37.746       37.746  ...     36.791     36.791
# hospital_beds_per_thousand          0.5          0.5  ...        1.7        1.7
# life_expectancy                   64.83        64.83  ...      61.49      61.49
# human_development_index           0.511        0.511  ...      0.571      0.571
# excess_mortality                    NaN          NaN  ...        NaN        NaN
#
# [61 rows x 112875 columns]

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# *Crie uma breve contextualização sobre o que será feito na fase de Análise Exploratória de Dados...*
#
# ...
#
# ...
#
# ### Análise Exploratória Inicial
#
# * *Visualizar as 5 primeiras entradas*
#     * `df.head()`
# * *Qual o tamanho do seu DataFrame*
#     * `df.shape`
# * *Extrair e imprimir os nomes das colunas*
#     * `df.columns`
# * *Quais os tipos das variáveis*
#     * `df.dtypes`
# * *Identifique a porcentagem de valores ausentes das colunas*
#     * `df.isnull().sum() / df.shape[0]` ou
#     * `(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)` *para ordem decrescente.*
# * *Transforme a coluna `date` no formato `datetime`*
#     * `df.date = pd.to_datetime(df.date)`
# * *Ver para a data mais atual, quais os países que têm mais casos e mortes. Veja o exemplo:*
#     * `df.loc[df.date == '2020-06-14'].sort_values(by="total_cases", ascending=False)`
#     * `df.loc[df.date == '2020-06-14'].sort_values(by="total_deaths", ascending=False)`
# * Plotar um gráfico de barras para os 5 países com mais mortes
#     * `df.loc[df.date == '2020-06-14', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:6]`
#     * `ax.bar('location', 'total_deaths', data=top5_total_deaths)`
# * Plotar um gráfico de linhas para ver a evolução do total de casos de COVID-19 no mundo.
#     * `df.loc[df.location == "World", "total_deaths"].reset_index(drop=True).plot()`
# * [OPCIONAL] Plotar um gráfico de dispersão considerando `gdp_per_capita` (ou seja, o PIB dos países) pelo número total de mortos. Pegue a data mais recente apenas.
#     * Lembre-se que não é nada conclusivo, pois envolve fatores como proporcão de testes, etc.

# %%
#Visualizar as 5 primeiras entradas
df_covid.head()
# Out:
#            iso_code continent  ... human_development_index  excess_mortality
# date                           ...
# 2020-02-24      AFG      Asia  ...                   0.511               NaN
# 2020-02-25      AFG      Asia  ...                   0.511               NaN
# 2020-02-26      AFG      Asia  ...                   0.511               NaN
# 2020-02-27      AFG      Asia  ...                   0.511               NaN
# 2020-02-28      AFG      Asia  ...                   0.511               NaN
#
# [5 rows x 61 columns]

# %%
#Avaliando o tamanho do dataset
print('Este dataset contém:')
print('{:,} entradas'.format(df_covid.shape[0]).replace(',','.'))
print('{} variáveis'.format(df_covid.shape[1]))
# Out:
# Este dataset contém:
# 112.660 entradas
# 61 variáveis

# %%
#exibindo todas as linhas para poder verificar o dataset
pd.set_option('display.max_rows',None)

#Nomes das colunas do Dataset
#fazer um dicionário com a tradução
df_covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index', 'excess_mortality'],
#       dtype='object')

# %%
#avaliando os tipos de variáveis em nosso dataset
#colocar a tradução do lado
pd.DataFrame(df_covid.dtypes, columns=['Tipo de Dados'])
# Out:
#                            Tipo de Dados
# iso_code                          object
# continent                         object
# location                          object
# total_cases                      float64
# new_cases                        float64
# ...                                  ...
# handwashing_facilities           float64
# hospital_beds_per_thousand       float64
# life_expectancy                  float64
# human_development_index          float64
# excess_mortality                 float64
#
# [61 rows x 1 columns]

# %%
#Avaliando a quantidade de valores ausentes nas colunas
#colocar o nome traduzido também
pd.DataFrame(((df_covid.isnull().sum() / df_covid.shape[0]).round(2)).sort_values(ascending=False),
             columns=['Fração de valores vazios'])
# Out:
#                                        Fração de valores vazios
# total_boosters_per_hundred                                 1.00
# total_boosters                                             1.00
# weekly_icu_admissions                                      0.99
# weekly_icu_admissions_per_million                          0.99
# weekly_hosp_admissions                                     0.98
# weekly_hosp_admissions_per_million                         0.98
# excess_mortality                                           0.97
# icu_patients                                               0.89
# icu_patients_per_million                                   0.89
# hosp_patients                                              0.87
# hosp_patients_per_million                                  0.87
# new_vaccinations                                           0.83
# people_fully_vaccinated_per_hundred                        0.83
# people_fully_vaccinated                                    0.83
# people_vaccinated                                          0.80
# people_vaccinated_per_hundred                              0.80
# total_vaccinations                                         0.79
# total_vaccinations_per_hundred                             0.79
# new_vaccinations_smoothed_per_million                      0.63
# new_vaccinations_smoothed                                  0.63
# new_tests_per_thousand                                     0.56
# total_tests                                                0.56
# new_tests                                                  0.56
# total_tests_per_thousand                                   0.56
# handwashing_facilities                                     0.55
# tests_per_case                                             0.52
# positive_rate                                              0.52
# new_tests_smoothed_per_thousand                            0.48
# new_tests_smoothed                                         0.48
# tests_units                                                0.47
# extreme_poverty                                            0.40
# male_smokers                                               0.31
# female_smokers                                             0.30
# reproduction_rate                                          0.20
# hospital_beds_per_thousand                                 0.19
# stringency_index                                           0.17
# new_deaths                                                 0.14
# total_deaths_per_million                                   0.14
# new_deaths_per_million                                     0.14
# total_deaths                                               0.14
# aged_70_older                                              0.12
# aged_65_older                                              0.12
# gdp_per_capita                                             0.11
# median_age                                                 0.11
# human_development_index                                    0.11
# cardiovasc_death_rate                                      0.11
# diabetes_prevalence                                        0.08
# population_density                                         0.07
# new_deaths_smoothed_per_million                            0.06
# new_cases_smoothed_per_million                             0.06
# continent                                                  0.05
# new_cases_smoothed                                         0.05
# life_expectancy                                            0.05
# new_deaths_smoothed                                        0.05
# total_cases_per_million                                    0.05
# new_cases_per_million                                      0.05
# new_cases                                                  0.04
# total_cases                                                0.04
# population                                                 0.01
# location                                                   0.00
# iso_code                                                   0.00

# %%
#retornando a exibir menos linhas
pd.set_option('display.max_rows',10)

# %% [markdown]
# Avaliando os Dados percebemos que algumas localidades estão voltando com o nome do continente. Além disso, para estes casos a coluna continent aparece como *NaN* ou seja está vazia.

# %%
#Verificando quais localidades tem o campo continente como nulo
df_continent_empty = df_covid[['continent','location']]
df_continent_empty[df_continent_empty['continent'].isna()]
# Out:
#            continent location
# date
# 2020-02-13       NaN   Africa
# 2020-02-14       NaN   Africa
# 2020-02-15       NaN   Africa
# 2020-02-16       NaN   Africa
# 2020-02-17       NaN   Africa
# ...              ...      ...
# 2021-08-24       NaN    World
# 2021-08-25       NaN    World
# 2021-08-26       NaN    World
# 2021-08-27       NaN    World
# 2021-08-28       NaN    World
#
# [5191 rows x 2 columns]

# %% [markdown]
# Dessa forma para evitar valores duplicados em nosso dataset iremos retirar os valores em que o continente está aparecendo e representando as localidades

# %%
#países sem os continentes na lista
df_lista_sem_continentes = df_covid[~df_covid['continent'].isna()]

# %%
#Avaliando os 10 paises tem mais casos no dia 28/08/2021
#melhor o gráfico e colocar os que tem mais mortes do lado (dois ax ax[0] e ax[1])
fig,ax = plt.subplots(figsize=(12,8))

df_paises_com_mais_casos = df_lista_sem_continentes.loc['2021-08-28'][['location','total_cases']].sort_values(
    by='total_cases',ascending=False)[:10]

ax.bar(data=df_paises_com_mais_casos,x='location',height='total_cases')
plt.show();

# %% [markdown]
# ### Análise Exploratória para o Brasil
#
# * Criar uma cópia do DataFrame apenas com o Brasil
#     * `df_brasil = df.loc[df.location == "Brazil"].copy()`
# * Identificar quando foi registrada a primeira morte no Brasil
# * Identificar quantos dias demorou para registrarmos a primeira morte, considerando o primeiro caso de COVID-19 registrado.
# * Plotar gráficos de linha em escalas linear e logarítmica para os casos totais e mortes totais.

# %% [markdown]
# ## Vacinação no Brasil

# %% [markdown]
# ### Obtenção dos Dados

# %%
endereco = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/completo/2021-08-26/part-00000-fc0c4a4e-3cdc-4044-8459-e277a2daa7a6-c000.csv'
df = dd.read_csv(urlpath=endereco,sep=';',dtype={'paciente_idade': 'float64','paciente_racacor_codigo': 'float64'})

# %%
df.head()
# Out:
#                                  document_id  ... id_sistema_origem
# 0  07369add-e7e5-4e23-bd5d-896c132e7305-i0b0  ...             18262
# 1  dfe1a8b2-6488-4f19-a55e-fb8da0e8e40d-i0b0  ...             18262
# 2  16d531bf-0d15-46e0-940a-fef77a6c48a1-i0b0  ...             18262
# 3  3f22731e-d52a-491a-8199-d33818fd523f-i0b0  ...             16341
# 4  1cba2138-06bd-4150-ad1d-7e638521e0d6-i0b0  ...             18262
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Conclusão
#
# *Escreva suas conclusões e análises sobre os dados relativos à COVID-19...*
